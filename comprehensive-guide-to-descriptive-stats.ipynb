# %%
#  First of all we need to import libraries
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Loading and Exploring the Dataset
#
# In this section, we will load the dataset and perform an initial exploration to understand its structure and contents. This step is crucial for any data analysis task as it helps in identifying the types of variables, their distributions, and any potential issues such as missing values.
#
#
# * The dataset we are using is "Sales_without_NaNs_v1.3.csv ". Let's start by loading the dataset and displaying the first few rows to get an overview.

# %% [markdown]
# # The dataset contains 10,000 entries and 7 columns.
# # Here's a brief overview of the columns:
#
# * Group: Indicates whether the customer was in the control or treatment group.
# * Customer Segment: Classifies customers based on their value to the company (e.g., High Value, Medium Value).
# * Sales Before: Sales amount before a certain event or intervention.
# * Sales After: Sales amount after the event or intervention.
# * Customer Satisfaction Before: Customer satisfaction score before the event or intervention.
# * Customer Satisfaction After: Customer satisfaction score after the event or intervention.
# * Purchase Made: Indicates whether a purchase was made ("Yes" or "No").

# %%
df = pd.read_csv('/kaggle/input/sales-and-satisfaction/Sales_without_NaNs_v1.3.csv')

# %%
# Display the first few rows
print( "First few rows of the dataset:")
display(df.head())


# Basic information about the dataset
print("\nBasic information about the dataset:")
df.info()


# Summary statistics for numerical columns
print("\nSummary statistics for numerical columns:")
display(df.describe())
# Out:
# First few rows of the dataset:
#        Group Customer_Segment  Sales_Before  Sales_After  \
# 0    Control       High Value    240.548359   300.007568
# 1  Treatment       High Value    246.862114   381.337555
# 2    Control       High Value    156.978084   179.330464
# 3    Control     Medium Value    192.126708   229.278031
# 4    Control       High Value    229.685623   270.167701
#
#    Customer_Satisfaction_Before  Customer_Satisfaction_After Purchase_Made
# 0                     74.684767                    74.093658            No
# 1                    100.000000                   100.000000           Yes
# 2                     98.780735                   100.000000            No
# 3                     49.333766                    39.811841           Yes
# 4                     83.974852                    87.738591           Yes
# Basic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# ...

# %%
# Frequencies of categorical columns
freq_group = df['Group'].value_counts()
freq_customer_segment = df['Customer_Segment'].value_counts()
freq_purchase_made = df['Purchase_Made'].value_counts()

# %%
# Visualizations for numerical data
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(df['Sales_Before'], kde=True, color='blue')
plt.title('Distribution of Sales Before')

plt.subplot(2, 2, 2)
sns.histplot(df['Sales_After'], kde=True, color='red')
plt.title('Distribution of Sales After')

plt.subplot(2, 2, 3)
sns.histplot(df['Customer_Satisfaction_Before'], kde=True, color='green')
plt.title('Distribution of Customer Satisfaction Before')

plt.subplot(2, 2, 4)
sns.histplot(df['Customer_Satisfaction_After'], kde=True, color='purple')
plt.title('Distribution of Customer Satisfaction After')

plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
